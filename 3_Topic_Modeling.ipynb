# %% [markdown]
# <a href="https://colab.research.google.com/github/tisRobin/BERT_Research_Project/blob/main/3_Topic_Modeling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import numpy as np
import pandas as pd

# %%
corpus = pd.read_csv('/content/gdrive/Shareddrives/Senior Thesis Report/Research Project/Platform Econ Pos.csv')

# %%
corpus.head()
# Out:
#                                             Sentence Sentiment
# 0   The Tech for Good Institute is a think tank c...  positive
# 1  The Institute seeks to create dialogue to fost...  positive
# 2  It also serves as a platform to enhance capabi...  positive
# 3  We believe this exchange of ideas and research...  positive
# 4  Across 63 offices in 38 countries, we work alo...  positive

# %%
len(corpus)
# Out:
# 940

# %%
pip install bertopic==0.12.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: bertopic==0.12.0 in /usr/local/lib/python3.7/dist-packages (0.12.0)
# Requirement already satisfied: umap-learn>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from bertopic==0.12.0) (0.5.3)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.7/dist-packages (from bertopic==0.12.0) (5.5.0)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.7/dist-packages (from bertopic==0.12.0) (4.64.1)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.7/dist-packages (from bertopic==0.12.0) (1.0.2)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from bertopic==0.12.0) (2.2.2)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.7/dist-packages (from bertopic==0.12.0) (1.3.5)
# Requirement already satisfied: hdbscan>=0.8.28 in /usr/local/lib/python3.7/dist-packages (from bertopic==0.12.0) (0.8.28)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.7/dist-packages (from bertopic==0.12.0) (1.21.6)
# Requirement already satisfied: pyyaml<6.0 in /usr/local/lib/python3.7/dist-packages (from bertopic==0.12.0) (5.4.1)
# Requirement already satisfied: cython>=0.27 in /usr/local/lib/python3.7/dist-packages (from hdbscan>=0.8.28->bertopic==0.12.0) (0.29.32)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.7/dist-packages (from hdbscan>=0.8.28->bertopic==0.12.0) (1.1.0)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.7/dist-packages (from hdbscan>=0.8.28->bertopic==0.12.0) (1.7.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.5->bertopic==0.12.0) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.5->bertopic==0.12.0) (2022.4)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from plotly>=4.7.0->bertopic==0.12.0) (8.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from plotly>=4.7.0->bertopic==0.12.0) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22.2.post1->bertopic==0.12.0) (3.1.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.4.1->bertopic==0.12.0) (1.12.1+cu113)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.4.1->bertopic==0.12.0) (0.10.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.4.1->bertopic==0.12.0) (0.13.1+cu113)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.4.1->bertopic==0.12.0) (3.7)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.4.1->bertopic==0.12.0) (0.1.97)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.4.1->bertopic==0.12.0) (4.22.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic==0.12.0) (2.23.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic==0.12.0) (5.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic==0.12.0) (3.8.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic==0.12.0) (21.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic==0.12.0) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.9->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic==0.12.0) (3.0.9)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic==0.12.0) (0.12.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic==0.12.0) (2022.6.2)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.7/dist-packages (from umap-learn>=0.5.0->bertopic==0.12.0) (0.5.7)
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.7/dist-packages (from umap-learn>=0.5.0->bertopic==0.12.0) (0.56.2)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic==0.12.0) (0.39.1)
# Requirement already satisfied: setuptools<60 in /usr/local/lib/python3.7/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic==0.12.0) (57.4.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic==0.12.0) (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk->sentence-transformers>=0.4.1->bertopic==0.12.0) (7.1.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic==0.12.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic==0.12.0) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic==0.12.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic==0.12.0) (2.10)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence-transformers>=0.4.1->bertopic==0.12.0) (7.1.2)

# %%
# !pip install joblib==1.1.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: joblib==1.1.0 in /usr/local/lib/python3.7/dist-packages (1.1.0)

# %%
from bertopic import BERTopic

# %%
sent = corpus['Sentence'].to_list()

# %%
from gensim.parsing.preprocessing import remove_stopwords


for index, sentence in enumerate(sent):
  filtered_sentence = remove_stopwords(sentence)
  sent[index] = filtered_sentence

# %%
topic_model = BERTopic(language="english") 
topics, probs = topic_model.fit_transform(sent)
# Out:
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
topic_model.get_topic_info()
# -1 and 0 stands for outliers  (so we have 19 topics)
# Out:
#     Topic  Count                                       Name
# 0      -1    277          -1_platform_platforms_the_workers
# 1       0    124                  0_gig_work_future_workers
# 2       1     64     1_platforms_digital_retail_competition
# 3       2     55         2_southeast_asia_economy_platforms
# 4       3     53            3_msmes_sales_digital_platforms
# 5       4     46          4_cent_work_internet_professional
# 6       5     40          5_women_pwds_persons_disabilities
# 7       6     30          6_food_delivery_covid19_consumers
# 8       7     30   7_policies_economy_policymakers_platform
# 9       8     29  8_ridehailing_driverpartners_grab_drivers
# 10      9     29       9_social_security_workers_protection
# 11     10     25         10_labour_digital_online_platforms
# 12     11     24      11_mobile_internet_subscribers_wallet
# 13     12     19         12_work_flexibility_income_greater
# 14     13     18       13_financial_inclusion_access_credit
# 15     14     18         14_skilling_companies_job_matching
# 16     15     16   15_logistics_ecommerce_infrastructure_us
# 17     16     15    16_financial_credit_underbanked_digital
# 18     17     15                     17_men_taxi_women_cent
# 19     18     13           18_consumers_o2o_platforms_agree

# %%
len(topic_model.get_topic_info())
# Out:
# 20

# %%
list(topic_model.get_topic_info()['Count'])
# Out:
# [277,
#  124,
#  64,
#  55,
#  53,
#  46,
#  40,
#  30,
#  30,
#  29,
#  29,
#  25,
#  24,
#  19,
#  18,
#  18,
#  16,
#  15,
#  15,
#  13]

# %%
import numpy as np
frequency = list(topic_model.get_topic_freq()['Count'])

ratio_rounded = []
for num in frequency:
  ratio = num/sum(frequency)
  ratio_rounded.append(round(ratio, 2))

ratio_rounded
# Out:
# [0.29,
#  0.13,
#  0.07,
#  0.06,
#  0.06,
#  0.05,
#  0.04,
#  0.03,
#  0.03,
#  0.03,
#  0.03,
#  0.03,
#  0.03,
#  0.02,
#  0.02,
#  0.02,
#  0.02,
#  0.02,
#  0.02,
#  0.01]

# %%
import pandas as pd

topic_info = topic_model.get_topic_info()
topic_info['Percentage'] = pd.Series(ratio_rounded)

topic_info = topic_info[['Topic', 'Count', 'Percentage', 'Name']]
topic_info
# Out:
#     Topic  Count  Percentage                                       Name
# 0      -1    277        0.29          -1_platform_platforms_the_workers
# 1       0    124        0.13                  0_gig_work_future_workers
# 2       1     64        0.07     1_platforms_digital_retail_competition
# 3       2     55        0.06         2_southeast_asia_economy_platforms
# 4       3     53        0.06            3_msmes_sales_digital_platforms
# 5       4     46        0.05          4_cent_work_internet_professional
# 6       5     40        0.04          5_women_pwds_persons_disabilities
# 7       6     30        0.03          6_food_delivery_covid19_consumers
# 8       7     30        0.03   7_policies_economy_policymakers_platform
# 9       8     29        0.03  8_ridehailing_driverpartners_grab_drivers
# 10      9     29        0.03       9_social_security_workers_protection
# 11     10     25        0.03         10_labour_digital_online_platforms
# 12     11     24        0.03      11_mobile_internet_subscribers_wallet
# 13     12     19        0.02         12_work_flexibility_income_greater
# 14     13     18        0.02       13_financial_inclusion_access_credit
# 15     14     18        0.02         14_skilling_companies_job_matching
# 16     15     16        0.02   15_logistics_ecommerce_infrastructure_us
# 17     16     15        0.02    16_financial_credit_underbanked_digital
# 18     17     15        0.02                     17_men_taxi_women_cent
# 19     18     13        0.01           18_consumers_o2o_platforms_agree

# %%
# important words for each topic and their c-TFIDF score 

topic_model.get_topic(5)
# Out:
# [('women', 0.16403483060870278),
#  ('pwds', 0.1257045948924879),
#  ('persons', 0.05405487928384886),
#  ('disabilities', 0.0507941718923701),
#  ('pwd', 0.041970181675538495),
#  ('empowering', 0.03119078138178363),
#  ('access', 0.030015330863031296),
#  ('platform', 0.028117080607598238),
#  ('gender', 0.027980121117025664),
#  ('economy', 0.02723701279674296)]

# %%
for i in list(topic_model.get_topic_info()['Topic']):
  print(f"Topic number: {i}, Important word: {topic_model.get_topic(i)[0]}")
# Out:
# Topic number: -1, Important word: ('platform', 0.023471355383736896)
# Topic number: 0, Important word: ('gig', 0.08372019950228808)
# Topic number: 1, Important word: ('platforms', 0.05206665472123635)
# Topic number: 2, Important word: ('southeast', 0.09111340045751633)
# Topic number: 3, Important word: ('msmes', 0.14957204757287768)
# Topic number: 4, Important word: ('cent', 0.12299836296058493)
# Topic number: 5, Important word: ('women', 0.16403483060870278)
# Topic number: 6, Important word: ('food', 0.14325388644826328)
# Topic number: 7, Important word: ('policies', 0.0756242076369367)
# Topic number: 8, Important word: ('ridehailing', 0.0890080483469158)
# Topic number: 9, Important word: ('social', 0.13042789796092405)
# Topic number: 10, Important word: ('labour', 0.0950608759640134)
# Topic number: 11, Important word: ('mobile', 0.19247065270004)
# Topic number: 12, Important word: ('work', 0.09663341462370677)
# Topic number: 13, Important word: ('financial', 0.17777877507518533)
# Topic number: 14, Important word: ('skilling', 0.1337858262275259)
# Topic number: 15, Important word: ('logistics', 0.24343807723272026)
# Topic number: 16, Important word: ('financial', 0.11130769868023066)
# Topic number: 17, Important word: ('men', 0.1057099435659591)
# Topic number: 18, Important word: ('consumers', 0.10786745840084881)

# %%
# dictionary of sample documents 

topic_model.get_representative_docs()
# Out:
# {2: ['The Platform Economy brings significant benefits propelling Southeast Asia’s digital ambitions.',
#   '109 109 There advantages ASEAN collaborate Platform Economy journey.',
#   'With collaboration stakeholders, Southeast Asia better chance growing region Platform Economy wider digital economy.'],
#  12: ['With flexible working arrangements Platforms, people gaining access variety income-generating sources replace supplement income traditional full-time work.',
#   'The result innovative ways working, flexibility workers businesses.',
#   'The uncertainty associated regularity available work income lead increased stress pressure workers.'],
#  18: ['Initial consumer participation Platform Economy positive 26% population wide range digital services, growth potential exists O2O services.',
#   'It promising start 83% consumers participated e-commerce, 1 3 consumers fully immersed Platform Economy O2O services.',
#   '39 Figure 10 Source: SEA-6 O2O Platforms Consumer Survey Bain & Company, May 2021 (N=2,800) How Platforms impact consumers’ quality life 8 10 Consumers agree Platform positive influence quality life Platforms provide consumers convenience making purchases taps mobile devices, need leave homes.'],
#  3: ['More support MSMEs, especially food sector, digitize help improve online sectoral sales 12%.',
#   'That said, international players gain access local consumers Platforms, creating competitive landscape local MSMEs.',
#   'Similarly, Malaysia, PENJANA MSMEs e-commerce campaign launched June 2020 successfully on-boarded 45,000 MSMEs e-commerce platforms helped 200,000 MSMEs adopt digitalisation solutions.'],
#  13: ['Such measure strengthen India’s complementary financial inclusion programmes MUDRA, mainstream formal lending individuals leveraging platforms earn living.',
#   'Platforms Southeast Asia enabling greater financial inclusion providing workers opportunities increase income personal savings, investing financial literacy.',
#   'Further innovation expansion new financial services potential financial inclusion engaged informal economy developing countries.'],
#  15: ['As adoption Platform Southeast Asia grows, demand last-mile delivery accelerate, making logistics sub-sector increasingly attractive investors.',
#   'In order grow logistics infrastructure, combination public private sector investments critical, shown promise driven growth e-commerce platforms.',
#   'Driven increased logistics investments, consumers MSMEs Southeast Asia-6 benefiting improved logistics conducting transactions Platforms.'],
#  1: ['Several retail platforms enabled SMEs individual entrepreneurs access larger customer base selling products platforms.',
#   'User data emerged valuable assets platforms, provides basis new products built serves improve efficiency productivity.',
#   'One major contributor rise digital economy availability open source platforms software applications (such Apache Hadoop, GitHub), accessed digital non-digital firms zero cost.'],
#  0: ['India’s Booming Gig Platform Economy: Perspectives Recommendations Future Work As discussed previous chapters, livelihood generation increased earning potential platform jobs, flexibility offer, apt new-age digital economy.',
#   'The real estate sector increased 1.7% 3.5% construction increased 1.2% 3.06% Table 11: Industrial Classification Gig Workers Percentage Share (2011-12 2019-20) National Industrial Classification 2008 (NIC-2008) 2011-12 2017-18 2018-19 2019-20 Manufacturing 9.09 10.50 10.03 9.17 Electricity, gas, steam air conditioning supplies 0.69 0.67 0.73 0.33 Water supply; sewerage, waste management remediation activities 0.00 0.59 0.49 0.47 Construction 1.24 2.31 2.58 3.06 Retail trade, motor vehicles motorcycles 41.97 36.48 40.30 38.95 Transportation storage 20.69 20.86 17.40 19.18 Accommodation Food service activities 5.49 6.05 5.20 5.94 Information communication 6.43 7.91 7.74 7.39 Financial insurance activities 9.32 7.78 8.98 9.21 Real estate activities 1.72 3.77 2.84 3.53 Administrative support service activities 0.64 0.36 0.68 0.55 Other education Group 0.08 0.38 0.58 0.67 Educational support services 2.64 2.34 2.44 1.56 Total 100.00 100.00 100.00 100.00 In terms occupation 2019-20, 22 lakh workers sales marketing persons, 12 lakh motor vehicle drivers, 6 lakh secretaries clerks, 5 lakh sales finance associates, others.',
#   'Therefore, increasing prominence gig platform workers acknowledged, India leverage potential new-age workforce.'],
#  16: ['This increased access financing result of, limited to, better credit risk assessment alternative data, lower fees wider distribution financial services digital channels, and/or enhanced fraud detection.',
#   'The provision digitized national ID systems, real-time payment systems, QR code standardization effective credit bureaus contribute competitive market allows easier switching reliance private digital infrastructure.',
#   'One driving force improved evaluation credit risks alternative data.'],
#  6: ['From consumer survey Bain & Company, 85% surveyed consumers agreed food delivery platforms helped cope better COVID-19.',
#   'Beyond providing continued access food, food delivery platforms enabled better food ordering experiences consumers.',
#   'With strong regional momentum, food delivery platform market expected reach US$23 billion 2025.'],
#  11: ['A higher mobile wallet percentage suggests better digital experience Platforms complete transition Platform Economy.',
#   'While COVID-19 accelerated adoption mobile internet mobile payments, country need continue expand penetration.',
#   'However, good progress 77% mobile internet subscribers (or 44% population) mobile wallet users.'],
#  7: ['In tandem, Platforms benefit policy’s predictability transparency.',
#   'When policies effect, Platforms better prepared able comply.',
#   'This better uphold policy intent protecting consumers businesses, supporting broader stability Platform Economy.'],
#  8: ['Hence, increases earnings driver-partners, providing affordable mobility solutions consumers.',
#   'For countries Indonesia, Philippines, Thailand, rising urbanization increasing population density (refer Figure 27), ride-hailing platforms potentially serve solution relieve pressure increasingly stretched public transport infrastructure.',
#   'c. The ride-hailing platform, Ola, supported local administration Bengaluru (Bruhat Bengaluru Mahanagara Palike, BBMP), India, provide transportation health workers visit people quarantined home ensure well-being.'],
#  14: ['Therefore, pursuing ends- outcomebased, platform-led models skilling job creation gathered attention industry associations proven successful.',
#   'Pursuing employer-led models job creation gathered attention industry associations proven successful (FICCI, 2017).',
#   'Therefore combination tech diffusion ability scale, services improved time algorithms better geographical, skill preferences matching.'],
#  10: ['Given increasing reliance businesses digital labour platforms fact platforms gradually shaping world work, relevant urgent better understand implications developments worker experience digital economy.',
#   'Many businesses relied digital labour platforms operating, reach new markets reduce costs.',
#   'A clearer understanding operation digital labour platforms, effective consistent approach them, essential.'],
#  5: ['WOMEN-RUN PLATFORMS Women-run firms platform economy fairly successful attracting retaining women workers past years.',
#   '2) Bridge Skill Gaps Carrying Out Periodic Assessments Partnering Platform Businesses Onboarding Skilled Women PwDs We need encourage platform-led skilling women PwDs productive members economy.',
#   'Platform work flexibility work hours work space offers, offer greater employment avenues different categories workers women Persons Disabilities (PwDs) well.'],
#  9: ['When coupled CoSS 2020, e-SHRAM portal expand scope social security giving large number platform workers access government sponsored schemes.',
#   'Platforms given rise innovative models provide social security benefits workers independent association platforms.',
#   'This existing evidence innovative social security provisions platform workers underscores potential truly leveraged, indicates need redesign social security programmes meet unique demands changing future work.'],
#  4: ['They tend highest self-employed workers.',
#   'For platform workers, hourly rate tends highest remote professional work, followed transport on-location work although, comes internet activities, selling tends bring largest income hour worked transport relatively high.',
#   'For estimates hours, number workers multiplied median online hours 5 week.'],
#  17: ['While figures represent considerable increase previous year 14 cent women compared 37 cent men owned smartphone, difference ownership men women remains stark (GSMA 2021).',
#   'In countries Chile India, considerably higher proportion app-based taxi drivers delivery workers highly educated compared traditional sectors.',
#   'Even fewer women engage app-based taxi delivery sectors, higher proportion highly educated (42 29 cent respectively) compared men (24 20 cent respectively).']}

# %%
# Topics Barchart 

topic_model.visualize_barchart(top_n_topics = 25)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="06e2fb29-06dc-4b3c-9047-ddb2d82703f3" class="plotly-graph-div" style="height:1250px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("06e2fb29-06dc-4b3c-9047-ddb2d82703f3")) {                    Plotly.newPlot(                        "06e2fb29-06dc-4b3c-9047-ddb2d82703f3",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.0365560555036729,0.03707469207025264,0.03898622202349078,0.04410340847873151,0.08372019950228808],"y":["indias  ","workers  ","future  ","work  ","gig  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.030206460291115084,0.030583339400351826,0.03356273365679454,0.044934576404894996,0.05206665472123635],"y":["rise  ","competition  ","retail  ","digital  ","platforms  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.03212975039605874,0.03336443629993036,0.034853049550334594,0.06774931461458428,0.09111340045751633],"y":["asias  ","platforms  ","economy  ","asia  ","southeast  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.04085946470066395,0.04685651496476041,0.05303648904750624,0.06492765027346972,0.14957204757287768],"y":["consumers  ","platforms  ","digital  ","sales  ","msmes  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.051057303726646235,0.058454705968529176,0.09516511474097925,0.10182039340114675,0.12299836296058493],"y":["workers  ","professional  ","internet  ","work  ","cent  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.041970181675538495,0.0507941718923701,0.05405487928384886,0.1257045948924879,0.16403483060870278],"y":["pwd  ","disabilities  ","persons  ","pwds  ","women  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.03838358185401545,0.04005078779512997,0.046532063457755395,0.1154778793423338,0.14325388644826328],"y":["grocery  ","consumers  ","covid19  ","delivery  ","food  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.046611115226199006,0.053084507474056866,0.07003745176440994,0.07012221323392238,0.0756242076369367],"y":["regulations  ","platform  ","policymakers  ","economy  ","policies  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.043614176886198126,0.04549182388660055,0.05623539887259191,0.06600228280247393,0.0890080483469158],"y":["2021  ","drivers  ","grab  ","driverpartners  ","ridehailing  "],"type":"bar","xaxis":"x9","yaxis":"y9"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.04819381937358316,0.053682949993861764,0.07535730389601263,0.12236994256618024,0.13042789796092405],"y":["worker  ","protection  ","workers  ","security  ","social  "],"type":"bar","xaxis":"x10","yaxis":"y10"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.04656689820594729,0.04924644145402779,0.059541632622486934,0.07671109541527643,0.0950608759640134],"y":["webbased  ","platforms  ","online  ","digital  ","labour  "],"type":"bar","xaxis":"x11","yaxis":"y11"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.06074631558301624,0.06074631558301624,0.06266397190780394,0.08557705054903096,0.19247065270004],"y":["or  ","wallet  ","subscribers  ","internet  ","mobile  "],"type":"bar","xaxis":"x12","yaxis":"y12"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.04813630813019249,0.04945670882409822,0.049794998026290935,0.07479172586065344,0.09663341462370677],"y":["hours  ","greater  ","income  ","flexibility  ","work  "],"type":"bar","xaxis":"x13","yaxis":"y13"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.06 ...

# %%
# hierarchical visualization

topic_model.visualize_hierarchy()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="8dd2553a-1257-4c65-aed2-ac97177d33b5" class="plotly-graph-div" style="height:485px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8dd2553a-1257-4c65-aed2-ac97177d33b5")) {                    Plotly.newPlot(                        "8dd2553a-1257-4c65-aed2-ac97177d33b5",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.9500358740972984,0.9500358740972984,0.0],"xaxis":"x","y":[-25.0,-25.0,-35.0,-35.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.9500358740972984,1.051259361001158,1.051259361001158,0.0],"xaxis":"x","y":[-30.0,-30.0,-45.0,-45.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.0,1.1648499867513349,1.1648499867513349,1.051259361001158],"xaxis":"x","y":[-15.0,-15.0,-37.5,-37.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[1.1648499867513349,1.255233974447214,1.255233974447214,0.0],"xaxis":"x","y":[-26.25,-26.25,-55.0,-55.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.0,1.2927183419970032,1.2927183419970032,1.255233974447214],"xaxis":"x","y":[-5.0,-5.0,-40.625,-40.625],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.0,1.0778604338399023,1.0778604338399023,0.0],"xaxis":"x","y":[-75.0,-75.0,-85.0,-85.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.0,1.3820489222578383,1.3820489222578383,1.0778604338399023],"xaxis":"x","y":[-65.0,-65.0,-80.0,-80.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.0,1.0592304265808963,1.0592304265808963,0.0],"xaxis":"x","y":[-115.0,-115.0,-125.0,-125.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.0,1.1992746320042098,1.1992746320042098,1.0592304265808963],"xaxis":"x","y":[-105.0,-105.0,-120.0,-120.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[1.1992746320042098,1.22413284768385,1.22413284768385,0.0],"xaxis":"x","y":[-112.5,-112.5,-135.0,-135.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.0,1.3256115119392373,1.3256115119392373,1.22413284768385],"xaxis":"x","y":[-95.0,-95.0,-123.75,-123.75],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.0,1.0169737198486577,1.0169737198486577,0.0],"xaxis":"x","y":[-145.0,-145.0,-155.0,-155.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[1.0169737198486577,1.2433572653851728,1.2433572653851728,0.0],"xaxis":"x","y":[-150.0,-150.0,-165.0,-165.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[1.3256115119392373,1.4610345146496018,1.4610345146496018,1.2433572653851728],"xaxis":"x","y":[-109.375,-109.375,-157.5,-157.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[1.3820489222578383,1.5620299718301542,1.5620299718301542,1.4610345146496018],"xaxis":"x","y":[-72.5,-72.5,-133.4375,-133.4375],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.0,1.0099019017569153,1.0099019017569153,0.0],"xaxis":"x","y":[-175.0,-175.0,-185.0,-185.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[1.5620299718301542,1.63 ...
